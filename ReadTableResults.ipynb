# %%
import pandas as pd

# %%
df = pd.read_excel('Risultati_multi_wake.xlsx')
df
# Out:
#          Unnamed: 0  AP_50  AP_75     AP  APs  APm  APl
# 0          faster50  0.762  0.271  0.119   -1  NaN  NaN
# 1         retina101  0.772  0.417  0.237   -1  NaN  NaN
# 2           mask101  0.791  0.327  0.082   -1  NaN  NaN
# 3         ssd_vgg16  0.198  0.046  0.201   -1  NaN  NaN
# 4      efficientdet  0.257  0.053  0.071   -1  NaN  NaN
# 5          fovea101  0.792  0.334  0.512   -1  NaN  NaN
# 6            mask50  0.757  0.257  0.257   -1  NaN  NaN
# 7           fovea50  0.744  0.310  0.322   -1  NaN  NaN
# 8            fsaf50  0.738  0.288  0.478   -1  NaN  NaN
# 9             htc50  0.779  0.339  0.289   -1  NaN  NaN
# 10   cascade_mask50  0.757  0.276  0.234   -1  NaN  NaN
# 11           htc101  0.743  0.308  0.425   -1  NaN  NaN
# 12    retina50_timm  0.216  0.006  0.021   -1  NaN  NaN
# 13    sparce_rcnn50  0.174  0.005  0.022   -1  NaN  NaN
# 14      retina_swin  0.719  0.256  0.321   -1  NaN  NaN
# 15           fcos50  0.714  0.267  0.412   -1  NaN  NaN
# ...
